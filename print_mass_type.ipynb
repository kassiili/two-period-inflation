# %%
# %load_ext autoreload
# %autoreload 2

# %config IPCompleter.greedy=True

# %%
import numpy as np

import importlib

import snapshot_obj
import trace_halo

# %%
importlib.reload(snapshot_obj)
importlib.reload(trace_halo)
# Out:
# <module 'trace_halo' from '/home/kasper/Curvaton_Simulations/APOSTLE_analysis/trace_halo.py'>

# %%
snap = snapshot_obj.Snapshot("CDM_V1_LR",127)
gns = snap.get_subhalos("GroupNumber")
sgns = snap.get_subhalos("SubGroupNumber")
masses = snap.get_subhalos("MassType")
for gn,sgn,m in zip(gns,sgns,masses):
    print("({},{}) : {:.2e}  {:.2e}  {:.2e}".format(int(gn),int(sgn),m[0],m[1],m[4]))
# Out:
# (1,0) : 2.64e+44  3.03e+45  1.07e+44
# (1,1) : 0.00e+00  5.50e+43  6.16e+41
# (1,2) : 0.00e+00  1.40e+43  2.78e+40
# (1,3) : 0.00e+00  8.37e+42  1.20e+40
# (1,4) : 0.00e+00  7.57e+42  8.43e+39
# (1,5) : 0.00e+00  7.19e+42  6.90e+39
# (1,6) : 0.00e+00  4.90e+42  6.74e+39
# (1,7) : 4.68e+41  2.00e+42  0.00e+00
# (1,8) : 0.00e+00  3.57e+42  5.90e+40
# (1,9) : 0.00e+00  2.83e+42  1.39e+41
# (1,10) : 0.00e+00  3.50e+42  1.37e+40
# (1,11) : 0.00e+00  3.47e+42  0.00e+00
# (1,12) : 0.00e+00  2.77e+42  0.00e+00
# (1,13) : 0.00e+00  2.43e+42  0.00e+00
# (1,14) : 0.00e+00  1.85e+42  0.00e+00
# (1,15) : 0.00e+00  1.72e+42  0.00e+00
# (1,16) : 0.00e+00  1.59e+42  0.00e+00
# (1,17) : 0.00e+00  1.17e+42  6.65e+39
# (1,18) : 0.00e+00  1.03e+42  8.47e+39
# (1,19) : 0.00e+00  1.03e+42  0.00e+00
# (1,20) : 0.00e+00  9.62e+41  5.11e+39
# (1,21) : 0.00e+00  9.91e+41  0.00e+00
# (1,22) : 0.00e+00  9.91e+41  0.00e+00
# (1,23) : 0.00e+00  9.18e+41  0.00e+00
# (1,24) : 0.00e+00  9.04e+41  0.00e+00
# ...
